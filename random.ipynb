# %%
import nflreadpy as nfl
import pathlib
import polars as pl
import numpy as np
from lib import data_processing_utils as data_utils
from lib import best_subset_utils as bs_utils
from lib import file_utils as o_utils

# %%
season_info = pl.read_excel(pathlib.Path.cwd() / "source/SeasonData.xlsx")

# %%
o_utils.output_source_frame(season_info, "SeasonData")
# Out:
# None
