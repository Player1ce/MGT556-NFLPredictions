# %%
import nflreadpy as nfl
import pathlib
import polars as pl
import numpy as np
from lib import data_processing_utils as data_utils
import matplotlib
from lib import best_subset_utils as bs_utils

# %%
season_info = pl.read_excel(pathlib.Path.cwd() / "data/SeasonData.xlsx")

# %%
data_utils.output_source_frame(season_info, "SeasonData")
# Out:
# None
# None
